# %%
import numpy as np
import math
import matplotlib.pyplot as plt
import random

# %%
def forwardX(L1,L2,shoulder,elbow):
    return L1*math.cos(shoulder) + L2*math.cos(shoulder+elbow)
def forwardY(L1,L2,shoulder,elbow):
    return L1*math.sin(shoulder) + L2*math.sin(shoulder+elbow)
def forward(L1,L2,shoulder,elbow):
    print('Horizonal:', forwardX(L1,L2,shoulder,elbow))
    print('Vertical:', forwardY(L1,L2,shoulder,elbow))

# %%
def bisection(L1, L2, x, y, a, b, d, e, TOL):
    print('Bisection')
    if L1 <= 0 or L2 <= 0:
        print('Please ensure both of your bone lengths are greater than 0.')
        return

    if np.abs(L1 - L2) > math.sqrt(x**2 + y**2) or math.sqrt(x**2 + y**2) > L1 + L2:
        print('Sorry, the arm cannot reach the point you provided.')
        return
    
    fa = (x - L1*math.cos(a))**2 + (y - L1*math.sin(a))**2 - L2**2
    fb = (x - L1*math.cos(b))**2 + (y - L1*math.sin(b))**2 - L2**2
            
    if np.sign(fa)*np.sign(fb) > 0:
        print('f(a)f(b)<0 not satisfied') 
        return # stop execution
    n=1            
    while np.abs(a-b)>TOL:
        c = (a+b)/2
        fc = (x - L1*math.cos(c))**2 + (y - L1*math.sin(c))**2 - L2**2 
        n=n+1
        #if np.isclose(f(c), 0):
        #    print('Approximate  root', c, 'has been obtained in', n, 'steps')
        #    return
        if np.sign(fc)*np.sign(fa)<0:
            b = c
            fb=fc
        else:
            a = c
            fa= fc
        #print(a, ', ', b)
        #print(fa, ', ', fb)
    c=(a+b)/2

    shoulder = c%(2*math.pi)
    print('Shoulder interval: [', np.degrees(a), np.degrees(b), ']')
    print('Approximate  angle', np.degrees(shoulder),' degrees has been obtained in', n, 'steps')

    gd = L1*math.sin(shoulder) + L2*math.sin(shoulder + d) - y
    ge = L1*math.sin(shoulder) + L2*math.sin(shoulder + e) - y

    if np.sign(gd)*np.sign(ge) > 0:
        print('g(d)g(e)<0 not satisfied') 
        return # stop execution
    m=1            
    while np.abs(d-e)>TOL:
        c = (d+e)/2
        gc = L1*math.sin(shoulder) + L2*math.sin(shoulder + c) - y   
        m=m+1
        #if np.isclose(g(c), 0):
        #    print('Approximate  root', c, 'has been obtained in', n, 'steps')
        #    return
        if np.sign(gc)*np.sign(gd)<0:
            e = c
            ge=gc
        else:
            d = c
            gd= gc
        #print(d, ', ', e)
        #print(gd, ', ', ge)    
        
    c=(d+e)/2

    elbow = c%(2*math.pi)

        
    print('Elbow interval: [', np.degrees(d), np.degrees(e), ']')
    print('Approximate  angle', np.degrees(elbow),' degrees has been obtained in', m, 'steps')
    if abs(L2*math.sin(elbow)/L1) <= 1:
        print('Elbow-down configuation: Shoulder at ', math.degrees(shoulder + math.asin(L2*math.sin(elbow)/L1))%360, ' degrees, and elbow at ', (180+math.degrees(elbow))%360,' degrees')
    else:
        print('Elbow-down configuation could not be found.')

bisection(1,1,-0.0481988113872,1.64996738863,.5,2,1,2,1e-40)
# Out:
# Bisection
# Shoulder interval: [ 57.29577951320702 57.29577951320702 ]
# Approximate  angle 57.29577951320702  degrees has been obtained in 55 steps
# Elbow interval: [ 68.7549354154441 68.7549354154441 ]
# Approximate  angle 68.7549354154441  degrees has been obtained in 54 steps
# Elbow-down configuation: Shoulder at  126.05071492865112  degrees, and elbow at  248.7549354154441  degrees

# %%
def newtonMethod(f,Df,x0,TOL,N):
    '''Approximate solution of f(x)=0 by Newton's method.
    Input
    ----------
    f : function
    Df : derivative of f(x).
    x0 :initial guess  
    TOL1: stopping criteria 
    N:  number of iterations 
    '''
    
    xn = x0
    for n in range(0,N):
        fxn = f(xn)
        Dfxn = Df(xn)
        if Dfxn == 0:
            print('Zero derivative. No solution found.')
            return None
        xn = xn - fxn/Dfxn
        if abs(fxn/Dfxn) < TOL:
            xn = xn%(2*math.pi)
            #print('Approximate solution', xn, 'after steps',n)
            return xn
    print('Exceeded maximum iterations. No solution found.')
    return None

def newtonSolution(L1,L2,x,y,b,TOL,N):
    print('Newton')
    if L1 <= 0 or L2 <= 0:
        print('Please ensure both of your bone lengths are greater than 0.')
        return

    if np.abs(L1 - L2) > math.sqrt(x**2 + y**2) or math.sqrt(x**2 + y**2) > L1 + L2:
        print('Sorry, the arm cannot reach the point you provided.')
        return

    def F(a):
        return (x - L1*math.cos(a))**2 + (y - L1*math.sin(a))**2 - L2**2
    def DF(a):
        return 2*(x - L1*math.cos(a))*L1*math.sin(a) - 2*(y - L1*math.sin(a))*L1*math.cos(a)
    shoulder = newtonMethod(F,DF,b,TOL,N)
    
    def G(a):
        return L1*math.sin(shoulder) + L2*math.sin(shoulder + a) - y
    def DG(a):
        return L2*math.cos(newtonMethod(F,DF,b,TOL,N) + a)
    elbow = newtonMethod(G,DG,b,TOL,N)
    
    print('Approximate angle of shoulder:',math.degrees(shoulder),'degrees')
    print('Approximate angle of elbow:',math.degrees(elbow),'degrees')
    if abs(L2*math.sin(elbow)/L1) <= 1:
        print('Elbow-down configuation: Shoulder at ', math.degrees(shoulder + math.asin(L2*math.sin(elbow)/L1))%360, ' degrees, and elbow at ', (180+math.degrees(elbow))%360,' degrees')
    else:
        print('Elbow-down configuation could not be found.')


newtonSolution(1,1,-0.0481988113872,1.64996738863,.8,1e-15,100)
# Out:
# Newton
# Approximate angle of shoulder: 57.295779513207016 degrees
# Approximate angle of elbow: 68.75493541544388 degrees
# Elbow-down configuation: Shoulder at  126.05071492865089  degrees, and elbow at  248.75493541544387  degrees

# %%
def g(L1,L2,x,y,a):
    return (x - L1*math.cos(a))**2 + (y - L1*math.sin(a))**2 - L2**2 + a

def h(L1,L2,y,a,b):
    return L1*math.sin(a) + L2*math.sin(a + b) - y + b

def fixedp(L1,L2,x,y,a0,b0,TOL,N):
    print('Fixed-point')
    if L1 <= 0 or L2 <= 0:
        print('Please ensure both of your bone lengths are greater than 0.')
        return

    if np.abs(L1 - L2) > math.sqrt(x**2 + y**2) or math.sqrt(x**2 + y**2) > L1 + L2:
        print('Sorry, the arm cannot reach the point you provided.')
        return
    
    e = 1
    i = 0
    ai = []
    while(e > TOL and i < N):
        a=g(L1,L2,x,y,a0)      # fixed point equation
        e= np.abs(a0-a) # error at the current step
        a0=a
        ai.append(a0)  # save the solution of the current step
        #print(ai,i)
        i= i + 1
    if e< TOL:
        print('Approximate angle of shoulder:', np.degrees(a0)%360,' degrees') 
    else:
        print('The first fixed point iteration diverges') 
        return(ai,i)
    
    e = 1
    i = 0
    bi = []
    while(e > TOL and i < N):
        b=h(L1,L2,y,a0,b0)      # fixed point equation
        e= np.abs(b0-b) # error at the current step
        b0=b
        bi.append(b0)  # save the solution of the current step
        #print(ai,i)
        i= i + 1
    if e< TOL:
        print('Approximate angle of elbow:', np.degrees(b0)%360,' degrees')
        if abs(L2*math.sin(b0)/L1) <= 1:
            print('Elbow-down configuation: Shoulder at ', math.degrees(a0 + math.asin(L2*math.sin(b0)/L1))%360, ' degrees, and elbow at ', (180+math.degrees(b0))%360,' degrees')
        else:
            print('Elbow-down configuation could not be found.')
    else:
        print('The second fixed point iteration diverges') 
        return(ai,i)

fixedp(1,1,-0.0481988113872,1.64996738863,.5,1,1e-5,100)
# Out:
# Fixed-point
# Approximate angle of shoulder: 57.29602917005287  degrees
# Approximate angle of elbow: 68.75452866156621  degrees
# Elbow-down configuation: Shoulder at  126.05055783161909  degrees, and elbow at  248.7545286615662  degrees

# %%
def threeMethods(L1,L2,x,y):
    guess = random.uniform(0,2*math.pi)
    guess2 = random.uniform(0,2*math.pi)
    bisection(L1,L2,x,y,(1e-10)*random.randint(0,1),guess,(1e-10)*random.randint(0,1),guess2,1e-5)
    print('')
    fixedp(L1,L2,x,y,guess,guess2,1e-5,10000)
    print('')
    newtonSolution(L1,L2,x,y,guess,1e-5,1000)

# %%
threeMethods(1,1,1,.8)
# Out:
# Bisection
# f(a)f(b)<0 not satisfied
#
# Fixed-point
# Approximate angle of shoulder: 348.47465025330115  degrees
# Approximate angle of elbow: 102.69454671043167  degrees
# Elbow-down configuation: Shoulder at  65.78010354286944  degrees, and elbow at  282.69454671043167  degrees
#
# Newton
# Approximate angle of shoulder: 348.4749283513514 degrees
# Approximate angle of elbow: 100.36975979076492 degrees
# Elbow-down configuation: Shoulder at  68.10516856058649  degrees, and elbow at  280.36975979076493  degrees

# %%
def randomThreeMethods():
    L1 = random.uniform(0,10)
    L2 = random.uniform(0,10)
    x = random.uniform(0, L1+L2)
    y = random.uniform(math.sqrt(max(0,(L1-L2)**2-x**2)),math.sqrt((L1+L2)**2-x**2))
    x = x*(-1)**random.randint(1,2)
    y = y*(-1)**random.randint(1,2)

    print('Upper arm length:', L1)
    print('Forearm length:', L2)
    print('Horizontal coordinate:', x)
    print('Vertical coordinatate:', y)
    threeMethods(L1,L2,x,y)

randomThreeMethods()
# Out:
# Upper arm length: 4.098521804828019
# Forearm length: 6.532137786070984
# Horizontal coordinate: -8.025823390327451
# Vertical coordinatate: 3.3572317952628112
# Bisection
# Shoulder interval: [ 111.60950828897889 111.61003851049516 ]
# Approximate  angle 111.60977339973702  degrees has been obtained in 19 steps
# Elbow interval: [ 72.3687694758815 72.36905923376311 ]
# Approximate  angle 72.36891435482231  degrees has been obtained in 20 steps
# Elbow-down configuation could not be found.
#
# Fixed-point
# The first fixed point iteration diverges
#
# Newton
# Approximate angle of shoulder: 111.60993392367061 degrees
# Approximate angle of elbow: 244.4115477930594 degrees
# Elbow-down configuation could not be found.

# %%
def checkMethods(L1,L2,shoulder,elbow):
    print('Upper arm length:',L1)
    print('Lower arm length:',L2)
    print('Shoulder:', math.degrees(shoulder))
    print('Elbow',math.degrees(elbow))
    forward(L1,L2,shoulder,elbow)
    threeMethods(L1,L2,forwardX(L1,L2,shoulder,elbow),forwardY(L1,L2,shoulder,elbow))
    print('')
    
checkMethods(1,1,.5,.6)
# Out:
# Upper arm length: 1
# Lower arm length: 1
# Shoulder: 28.64788975654116
# Elbow 34.37746770784939
# Horizonal: 1.33117868331595
# Vertical: 1.3706328986656384
# Bisection
# Shoulder interval: [ 28.64772187614286 28.6480600699601 ]
# Approximate  angle 28.647890973051478  degrees has been obtained in 18 steps
# g(d)g(e)<0 not satisfied
#
# Fixed-point
# Approximate angle of shoulder: 28.647877300455534  degrees
# Approximate angle of elbow: 88.32732933016675  degrees
# Elbow-down configuation: Shoulder at  116.97520663062237  degrees, and elbow at  268.3273293301668  degrees
#
# Newton
# Approximate angle of shoulder: 28.647889756541154 degrees
# Approximate angle of elbow: 34.37746770688771 degrees
# Elbow-down configuation: Shoulder at  63.02535746342886  degrees, and elbow at  214.3774677068877  degrees

# %%
def checkMethodsRandom():
    checkMethods(random.uniform(0,10),random.uniform(0,10),random.uniform(0,2*math.pi),random.uniform(0,2*math.pi))

checkMethodsRandom()
# Out:
# Upper arm length: 3.8192622756454595
# Lower arm length: 9.68587299797581
# Shoulder: 25.434477731887085
# Elbow 328.8388000643567
# Horizonal: 13.08662014693439
# Vertical: 0.6737981190304839
# Bisection
# Shoulder interval: [ 25.434182867392902 25.43448090792422 ]
# Approximate  angle 25.43433188765856  degrees has been obtained in 21 steps
# Elbow interval: [ 160.29206303344793 160.2925408041276 ]
# Approximate  angle 160.29230191878776  degrees has been obtained in 20 steps
# Elbow-down configuation: Shoulder at  84.21772981271107  degrees, and elbow at  340.29230191878776  degrees
#
# Fixed-point
# The first fixed point iteration diverges
#
# Newton
# Approximate angle of shoulder: 340.4603565255355 degrees
# Approximate angle of elbow: 31.161199935643545 degrees
# Elbow-down configuation could not be found.

# %%
checkMethodsRandom()
checkMethodsRandom()
checkMethodsRandom()
checkMethodsRandom()
checkMethodsRandom()
checkMethodsRandom()
checkMethodsRandom()
checkMethodsRandom()
checkMethodsRandom()
checkMethodsRandom()

checkMethodsRandom()
checkMethodsRandom()
checkMethodsRandom()
checkMethodsRandom()
checkMethodsRandom()
checkMethodsRandom()
checkMethodsRandom()
checkMethodsRandom()
checkMethodsRandom()
checkMethodsRandom()

checkMethodsRandom()
checkMethodsRandom()
checkMethodsRandom()
checkMethodsRandom()
checkMethodsRandom()
checkMethodsRandom()
checkMethodsRandom()
checkMethodsRandom()
checkMethodsRandom()
checkMethodsRandom()

checkMethodsRandom()
checkMethodsRandom()
checkMethodsRandom()
checkMethodsRandom()
checkMethodsRandom()
checkMethodsRandom()
checkMethodsRandom()
checkMethodsRandom()
checkMethodsRandom()
checkMethodsRandom()

checkMethodsRandom()
checkMethodsRandom()
checkMethodsRandom()
checkMethodsRandom()
checkMethodsRandom()
checkMethodsRandom()
checkMethodsRandom()
checkMethodsRandom()
checkMethodsRandom()
checkMethodsRandom()
# Out:
# Upper arm length: 7.716559889809456
# Lower arm length: 1.1092635786612481
# Shoulder: 327.18251747287707
# Elbow 148.14187286982826
# Horizonal: 6.010527382217635
# Vertical: -3.179438843717799
# Bisection
# f(a)f(b)<0 not satisfied
#
# Fixed-point
# The first fixed point iteration diverges
#
# Newton
# Approximate angle of shoulder: 327.1825174728766 degrees
# Approximate angle of elbow: 97.49309218442373 degrees
# Elbow-down configuation: Shoulder at  335.37641421276044  degrees, and elbow at  277.49309218442374  degrees
#
# Upper arm length: 0.05032387243931957
# Lower arm length: 8.298350808261114
# Shoulder: 79.54280854238843
# Elbow 300.8846922745507
# Horizonal: 7.785639307411071
# Vertical: 2.9457940623727583
# Bisection
# Shoulder interval: [ 79.54250272529951 79.54298719405561 ]
# Approximate  angle 79.54274495967756  degrees has been obtained in 20 steps
# g(d)g(e)<0 not satisfied
#
# Fixed-point
# Approximate angle of shoulder: 321.9065868143739  degrees
# The second fixed point iteration diverges
#
# Newton
# Approximate angle of shoulder: 321.9067189445078 degrees
# Approximate angle of elbow: 197.07125438553558 degrees
# Elbow-down configuation could not be found.
#
# Upper arm length: 3.8099027370258054
# Lower arm length: 9.891095414819967
# Shoulder: 48.13027548004302
# Elbow 143.87009085599493
# Horizonal: -7.1320598060309175
# Vertical: 0.7805624363014583
# Bisection
# Shoulder interval: [ 48.13011974987547 48.13054284205135 ]
# Approximate  angle 48.13033129596341  degrees has been obtained in 20 steps
# g(d)g(e)<0 not satisfied
#
# Fixed-point
# The first fixed point iteration diverges
#
# Newton
# Approximate angle of shoulder: 299.3780621676814 degrees
# Approximate angle of elbow: 216.12990914402332 degrees
# Elbow-down configuation could not be found.
#
# Upper arm length: 8.192465710773835
# Lower arm length: 7.91260406423016
# Shoulder: 206.1521473993226
# Elbow 262.0693835605351
# Horizonal: -9.827983809489243
# Vertical: 3.9049424208477794
# Bisection
# f(a)f(b)<0 not satisfied
#
# Fixed-point
# The first fixed point iteration diverges
#
# Newton
# Approximate angle of shoulder: 110.50913896997656 degrees
# Approximate angle of elbow: 221.0511056205819 degrees
# Elbow-down configuation: Shoulder at  71.14124453062877  degrees, and elbow at  41.05110562058189  degrees
#
# Upper arm length: 2.6039999428290495
# Lower arm length: 0.9736908164735592
# Shoulder: 296.2870078411234
# Elbow 29.86368734169987
# Horizonal: 1.9618835068137561
# Vertical: -2.877068181047513
# Bisection
# f(a)f(b)<0 not satisfied
#
# Fixed-point
# The first fixed point iteration diverges
#
# Newton
# Approximate angle of shoulder: 296.28700784112334 degrees
# Approximate angle of elbow: 277.56229697603135 degrees
# Elbow-down configuation: Shoulder at  274.5301269762484  degrees, and elbow at  97.56229697603135  degrees
#
# Upper arm length: 6.692472650596467
# Lower arm length: 0.7835142756721969
# Shoulder: 287.999501685195
# Elbow 84.25840484754497
# Horizonal: 2.8336840005253245
# Vertical: -6.19858781807164
# Bisection
# f(a)f(b)<0 not satisfied
#
# Fixed-point
# The first fixed point iteration diverges
#
# Newton
# Approximate angle of shoulder: 301.13551155424625 degrees
# Approximate angle of elbow: 21.987381722609793 degrees
# Elbow-down configuation: Shoulder at  303.64774921005244  degrees, and elbow at  201.9873817226098  degrees
#
# Upper arm length: 4.53335146211934
# Lower arm length: 7.5362812645653
# Shoulder: 306.14162757387857
# Elbow 296.94156638331145
# Horizonal: -0.737951736394372
# Vertical: -10.380797142994444
# Bisection
# f(a)f(b)<0 not satisfied
#
# Fixed-point
# The first fixed point iteration diverges
#
# Newton
# Approximate angle of shoulder: 225.72595041726362 degrees
# Approximate angle of elbow: 25.489665544332652 degrees
# Elbow-down configuation: Shoulder at  271.40313666965136  degrees, and elbow at  205.48966554433264  degrees
#
# Upper arm length: 9.937454088422077
# Lower arm length: 5.675039640854342
# Shoulder: 81.87462873668473
# Elbow 224.8653597556684
# Horizonal: 4.7992771448701745
# Vertical: 5.289953263931162
# Bisection
# f(a)f(b)<0 not satisfied
#
# Fixed-point
# The first fixed point iteration diverges
#
# Newton
# Approximate angle of shoulder: 81.87462873823533 degrees
# Approximate angle of elbow: 151.38538277005307 degrees
# Elbow-down configuation: Shoulder at  97.74710862247058  degrees, and elbow at  331.38538277005307  degrees
#
# Upper arm length: 3.0351467999032566
# Lower arm length: 2.843356954315499
# Shoulder: 208.5283559176375
# Elbow 13.890027929259615
# Horizonal: -4.765698720709437
# Vertical: -3.3675227726238095
# Bisection
# f(a)f(b)<0 not satisfied
#
# Fixed-point
# The first fixed point iteration diverges
#
# Newton
# Approximate angle of shoulder: 221.96298288157314 degrees
# Approximate angle of elbow: 346.1099720688829 degrees
# Elbow-down configuation: Shoulder at  208.96658233951314  degrees, and elbow at  166.10997206888283  degrees
#
# Upper arm length: 1.981047341958887
# Lower arm length: 3.615964824927521
# Shoulder: 347.6013355481332
# Elbow 83.42801664107307
# Horizonal: 3.110335268622629
# Vertical: 2.9942088060186607
# Bisection
# Shoulder interval: [ 100.21894540457987 100.21925789349642 ]
# Approximate  angle 100.21910164903814  degrees has been obtained in 20 steps
# Elbow interval: [ 62.989740105627305 62.99026114274359 ]
# Approximate  angle 62.99000062418545  degrees has been obtained in 20 steps
# Elbow-down configuation could not be found.
#
# Fixed-point
# The first fixed point iteration diverges
#
# Newton
# Approximate angle of shoulder: 100.2190573568457 degrees
# Approximate angle of elbow: 62.98990192809587 degrees
# Elbow-down configuation could not be found.
#
# Upper arm length: 0.7774090125046562
# Lower arm length: 1.3326174289234416
# Shoulder: 143.96753191987028
# Elbow 256.43358620947527
# Horizonal: 0.3861443062786911
# Vertical: 1.321021562683236
# Bisection
# f(a)f(b)<0 not satisfied
#
# Fixed-point
# The first fixed point iteration diverges
#
# Newton
# Approximate angle of shoulder: 143.96753191998758 degrees
# Approximate angle of elbow: 256.43358620943064 degrees
# Elbow-down configuation could not be found.
#
# Upper arm length: 7.646190761362347
# Lower arm length: 0.6837114785966181
# Shoulder: 336.55488008272533
# Elbow 7.713664126982778
# Horizonal: 7.6730351399350525
# Vertical: -3.2275676341972153
# Bisection
# f(a)f(b)<0 not satisfied
#
# Fixed-point
# Approximate angle of shoulder: 336.55472266231664  degrees
# Approximate angle of elbow: 219.17531195448558  degrees
# Elbow-down configuation: Shoulder at  333.31663013692014  degrees, and elbow at  39.17531195448555  degrees
#
# Newton
# Approximate angle of shoulder: 337.8182078735093 degrees
# Approximate angle of elbow: 352.28633586583976 degrees
# Elbow-down configuation: Shoulder at  337.1305282196715  degrees, and elbow at  172.28633586583976  degrees
#
# Upper arm length: 2.38490731073611
# Lower arm length: 5.746309336807389
# Shoulder: 152.23603699536446
# Elbow 290.67942671442216
# Horizonal: -1.4016295077002772
# Vertical: 6.813399561969201
# Bisection
# Shoulder interval: [ 51.012625634525165 51.0131947305071 ]
# Approximate  angle 51.01291018251614  degrees has been obtained in 19 steps
# Elbow interval: [ 8.65350891836807 8.653926861324765 ]
# Approximate  angle 8.653717889846419  degrees has been obtained in 16 steps
# Elbow-down configuation: Shoulder at  72.26862595664882  degrees, and elbow at  188.6537178898464  degrees
#
# Fixed-point
# The first fixed point iteration diverges
#
# Newton
# Approximate angle of shoulder: 152.23603699537475 degrees
# Approximate angle of elbow: 304.84849929480805 degrees
# Elbow-down configuation could not be found.
#
# Upper arm length: 4.895526913793011
# Lower arm length: 4.916834981399253
# Shoulder: 100.16654689730538
# Elbow 30.590784896394403
# Horizonal: -4.074098405315997
# Vertical: 8.543072717185666
# Bisection
# Shoulder interval: [ 100.16640506317168 100.16690282648614 ]
# Approximate  angle 100.16665394482891  degrees has been obtained in 19 steps
# Elbow interval: [ 30.590550952465378 30.59107353734241 ]
# Approximate  angle 30.59081224490389  degrees has been obtained in 20 steps
# Elbow-down configuation: Shoulder at  130.9050095227757  degrees, and elbow at  210.5908122449039  degrees
#
# Fixed-point
# The first fixed point iteration diverges
#
# Newton
# Approximate angle of shoulder: 130.8253856596267 degrees
# Approximate angle of elbow: 308.94001357701626 degrees
# Elbow-down configuation: Shoulder at  79.45573940713152  degrees, and elbow at  128.94001357701626  degrees
#
# Upper arm length: 0.3435495938157229
# Lower arm length: 7.184372325538813
# Shoulder: 116.0665716173273
# Elbow 114.87747306279479
# Horizonal: -4.6776834241325576
# Vertical: -5.270282644330787
# Bisection
# Shoulder interval: [ 116.06621822824297 116.06663668544311 ]
# Approximate  angle 116.06642745684304  degrees has been obtained in 20 steps
# g(d)g(e)<0 not satisfied
#
# Fixed-point
# The first fixed point iteration diverges
#
# Newton
# Approximate angle of shoulder: 116.0665716173274 degrees
# Approximate angle of elbow: 192.9893837028883 degrees
# Elbow-down configuation could not be found.
#
# Upper arm length: 9.77652833426456
# Lower arm length: 2.2854114892977497
# Shoulder: 216.2118215355564
# Elbow 230.02595815511896
# Horizonal: -7.738119395320147
# Vertical: -3.4952143567435163
# Bisection
# f(a)f(b)<0 not satisfied
#
# Fixed-point
# The first fixed point iteration diverges
#
# Newton
# Approximate angle of shoulder: 192.40440826138212 degrees
# Approximate angle of elbow: 129.9740418448479 degrees
# Elbow-down configuation: Shoulder at  202.7242276028358  degrees, and elbow at  309.9740418448479  degrees
#
# Upper arm length: 1.120276440884711
# Lower arm length: 7.979266686203558
# Shoulder: 19.559919129019853
# Elbow 113.3658467804213
# Horizonal: -4.378653969646669
# Vertical: 6.217772068839326
# Bisection
# f(a)f(b)<0 not satisfied
#
# Fixed-point
# The first fixed point iteration diverges
#
# Newton
# Approximate angle of shoulder: 19.559919129024532 degrees
# Approximate angle of elbow: 27.514314960165112 degrees
# Elbow-down configuation could not be found.
#
# Upper arm length: 0.5574878793717353
# Lower arm length: 1.0757362396231362
# Shoulder: 156.35885073691608
# Elbow 5.747528260235515
# Horizonal: -1.5344020808159424
# Vertical: 0.5540772520032033
# Bisection
# f(a)f(b)<0 not satisfied
#
# Fixed-point
# Approximate angle of shoulder: 156.35486933015886  degrees
# Approximate angle of elbow: 5.753495476507193  degrees
# Elbow-down configuation: Shoulder at  167.50855721243306  degrees, and elbow at  185.7534954765072  degrees
#
# Newton
# Approximate angle of shoulder: 156.35885073691605 degrees
# Approximate angle of elbow: 5.747528260633918 degrees
# Elbow-down configuation: Shoulder at  167.5008618194706  degrees, and elbow at  185.7475282606339  degrees
#
# Upper arm length: 2.1156549746160067
# Lower arm length: 3.3747165112058153
# Shoulder: 252.86702778151263
# Elbow 19.211874505536063
# Horizonal: -0.5008311539825357
# Vertical: -5.394265253787415
# Bisection
# f(a)f(b)<0 not satisfied
#
# Fixed-point
# The first fixed point iteration diverges
#
# Newton
# Approximate angle of shoulder: 276.5241200180672 degrees
# Approximate angle of elbow: 340.788125494464 degrees
# Elbow-down configuation: Shoulder at  244.8630893418354  degrees, and elbow at  160.788125494464  degrees
#
# Upper arm length: 1.317166171741111
# Lower arm length: 4.814006185266354
# Shoulder: 22.561301872990523
# Elbow 24.005780478693502
# Horizonal: 4.5260153736673985
# Vertical: 4.001193442128654
# Bisection
# f(a)f(b)<0 not satisfied
#
# Fixed-point
# The first fixed point iteration diverges
#
# Newton
# Approximate angle of shoulder: 60.394845941855365 degrees
# Approximate angle of elbow: 83.2160885960942 degrees
# Elbow-down configuation could not be found.
#
# Upper arm length: 6.531075938333411
# Lower arm length: 2.6524630465733923
# Shoulder: 132.2344569889067
# Elbow 192.9749187854375
# Horizonal: -2.2116514317491487
# Vertical: 3.322171662094417
# Bisection
# f(a)f(b)<0 not satisfied
#
# Fixed-point
# The first fixed point iteration diverges
#
# Newton
# Approximate angle of shoulder: 132.2344569889067 degrees
# Approximate angle of elbow: 192.9749187854375 degrees
# Elbow-down configuation: Shoulder at  127.00261427303214  degrees, and elbow at  12.974918785437467  degrees
#
# Upper arm length: 8.517632179942307
# Lower arm length: 8.925161812114151
# Shoulder: 165.5802738090214
# Elbow 208.75310615083694
# Horizonal: 0.3980310822606583
# Vertical: 4.3306336239767145
# Bisection
# Shoulder interval: [ 3.9167685419138394 3.9170593622684713 ]
# Approximate  angle 3.916913952091155  degrees has been obtained in 20 steps
# g(d)g(e)<0 not satisfied
#
# Fixed-point
# The first fixed point iteration diverges
#
# Newton
# Approximate angle of shoulder: 165.58027380917991 degrees
# Approximate angle of elbow: 208.75310615082967 degrees
# Elbow-down configuation: Shoulder at  135.31185293842552  degrees, and elbow at  28.753106150829694  degrees
#
# Upper arm length: 5.625960777454377
# Lower arm length: 6.0027861769522985
# Shoulder: 80.94146325057802
# Elbow 285.28875857521683
# Horizonal: 6.853103629353454
# Vertical: 6.207238529843519
# Bisection
# f(a)f(b)<0 not satisfied
#
# Fixed-point
# The first fixed point iteration diverges
#
# Newton
# Approximate angle of shoulder: 80.94146325103671 degrees
# Approximate angle of elbow: 285.28875857469006 degrees
# Elbow-down configuation could not be found.
#
# Upper arm length: 7.139462191954288
# Lower arm length: 1.4457493638979024
# Shoulder: 312.3205167034241
# Elbow 342.476742980204
# Horizonal: 5.413197784882084
# Vertical: -6.591295039523181
# Bisection
# f(a)f(b)<0 not satisfied
#
# Fixed-point
# The first fixed point iteration diverges
#
# Newton
# Approximate angle of shoulder: 306.4695894552248 degrees
# Approximate angle of elbow: 269.5375640685782 degrees
# Elbow-down configuation: Shoulder at  294.78671714306927  degrees, and elbow at  89.5375640685782  degrees
#
# Upper arm length: 6.585099845745384
# Lower arm length: 6.731437325997264
# Shoulder: 283.99672397173214
# Elbow 48.0414688610558
# Horizonal: 7.538326134592925
# Vertical: -9.545841128708451
# Bisection
# f(a)f(b)<0 not satisfied
#
# Fixed-point
# The first fixed point iteration diverges
#
# Newton
# Approximate angle of shoulder: 332.5993950696423 degrees
# Approximate angle of elbow: 282.8426787216417 degrees
# Elbow-down configuation: Shoulder at  247.29010904786387  degrees, and elbow at  102.84267872164168  degrees
#
# Upper arm length: 7.257382683586315
# Lower arm length: 0.8252199262534099
# Shoulder: 75.90926371958426
# Elbow 180.3111399860839
# Horizonal: 1.5703121437032606
# Vertical: 6.237548726708464
# Bisection
# f(a)f(b)<0 not satisfied
#
# Fixed-point
# Approximate angle of shoulder: 75.82226296409499  degrees
# Approximate angle of elbow: 179.63259451716215  degrees
# Elbow-down configuation: Shoulder at  75.86403949535452  degrees, and elbow at  359.63259451716215  degrees
#
# Newton
# Approximate angle of shoulder: 75.82942679477704 degrees
# Approximate angle of elbow: 208.65229803759445 degrees
# Elbow-down configuation: Shoulder at  72.70399489453695  degrees, and elbow at  28.65229803759445  degrees
#
# Upper arm length: 2.436324951346881
# Lower arm length: 9.198723336814629
# Shoulder: 278.09327841692607
# Elbow 303.8849382793522
# Horizonal: -6.495325060756988
# Vertical: -8.56460749886599
# Bisection
# f(a)f(b)<0 not satisfied
#
# Fixed-point
# The first fixed point iteration diverges
#
# Newton
# Approximate angle of shoulder: 278.0932784170547 degrees
# Approximate angle of elbow: 303.88493827923 degrees
# Elbow-down configuation could not be found.
#
# Upper arm length: 0.39452533922994637
# Lower arm length: 0.43378195986057744
# Shoulder: 356.94048734390094
# Elbow 94.33011374698253
# Horizonal: 0.38434416153837947
# Vertical: 0.41261822270727416
# Bisection
# f(a)f(b)<0 not satisfied
#
# Fixed-point
# Approximate angle of shoulder: 356.94150724745043  degrees
# Approximate angle of elbow: 94.4260150434274  degrees
# Elbow-down configuation could not be found.
#
# Newton
# Approximate angle of shoulder: 356.9404873438889 degrees
# Approximate angle of elbow: 91.78891156571505 degrees
# Elbow-down configuation could not be found.
#
# Upper arm length: 8.741960551374707
# Lower arm length: 5.119723055214205
# Shoulder: 161.91241601110858
# Elbow 148.06510558487258
# Horizonal: -5.020603745564095
# Vertical: -1.2091058004126092
# Bisection
# f(a)f(b)<0 not satisfied
#
# Fixed-point
# The first fixed point iteration diverges
#
# Newton
# Approximate angle of shoulder: 161.91241601110858 degrees
# Approximate angle of elbow: 68.11006239126978 degrees
# Elbow-down configuation: Shoulder at  194.82951555433897  degrees, and elbow at  248.11006239126976  degrees
#
# Upper arm length: 2.7430905029881525
# Lower arm length: 4.677318700106431
# Shoulder: 253.69018813844824
# Elbow 161.5623144178489
# Horizonal: 1.8955436124159242
# Vertical: 1.2105201329673907
# Bisection
# Shoulder interval: [ 171.43515384975856 171.43561135177032 ]
# Approximate  angle 171.43538260076443  degrees has been obtained in 20 steps
# g(d)g(e)<0 not satisfied
#
# Fixed-point
# The first fixed point iteration diverges
#
# Newton
# Approximate angle of shoulder: 253.69018813850448 degrees
# Approximate angle of elbow: 231.05730930518212 degrees
# Elbow-down configuation could not be found.
#
# Upper arm length: 9.357249596677192
# Lower arm length: 8.963178418579275
# Shoulder: 87.14795836301585
# Elbow 206.21811989044608
# Horizonal: 4.020424930333885
# Vertical: 1.1175547642688048
# Bisection
# Shoulder interval: [ 87.14778377748347 87.14807794821071 ]
# Approximate  angle 87.14793086284709  degrees has been obtained in 20 steps
# Elbow interval: [ 159.4857646387306 159.48607151031334 ]
# Approximate  angle 159.48591807452198  degrees has been obtained in 20 steps
# Elbow-down configuation: Shoulder at  106.76177924027905  degrees, and elbow at  339.485918074522  degrees
#
# Fixed-point
# The first fixed point iteration diverges
#
# Newton
# Approximate angle of shoulder: 87.147958363016 degrees
# Approximate angle of elbow: 159.48596338352212 degrees
# Elbow-down configuation: Shoulder at  106.76176358794244  degrees, and elbow at  339.4859633835221  degrees
#
# Upper arm length: 1.0991655187535787
# Lower arm length: 0.3954459355945317
# Shoulder: 86.20835303524034
# Elbow 127.37380092633393
# Horizonal: -0.25675737224597595
# Vertical: 0.8780257398261371
# Bisection
# f(a)f(b)<0 not satisfied
#
# Fixed-point
# Approximate angle of shoulder: 86.20845754445679  degrees
# Approximate angle of elbow: 127.37453813095367  degrees
# Elbow-down configuation: Shoulder at  102.8212913610223  degrees, and elbow at  307.3745381309537  degrees
#
# Newton
# Approximate angle of shoulder: 126.39220938862562 degrees
# Approximate angle of elbow: 232.62619907373843 degrees
# Elbow-down configuation: Shoulder at  109.77920756369627  degrees, and elbow at  52.62619907373846  degrees
#
# Upper arm length: 9.064510188543013
# Lower arm length: 0.6822171908756236
# Shoulder: 55.65082047049357
# Elbow 326.7979490415581
# Horizonal: 5.7450328498281795
# Vertical: 7.744298696381067
# Bisection
# f(a)f(b)<0 not satisfied
#
# Fixed-point
# The first fixed point iteration diverges
#
# Newton
# Approximate angle of shoulder: 55.650820470514454 degrees
# Approximate angle of elbow: 326.7979490413667 degrees
# Elbow-down configuation: Shoulder at  53.2888090273421  degrees, and elbow at  146.79794904136668  degrees
#
# Upper arm length: 9.403906774268304
# Lower arm length: 4.815971908078669
# Shoulder: 194.69435082463662
# Elbow 323.1800566577551
# Horizonal: -13.557657103173216
# Vertical: -0.5715407770740764
# Bisection
# f(a)f(b)<0 not satisfied
#
# Fixed-point
# The first fixed point iteration diverges
#
# Newton
# Approximate angle of shoulder: 170.13354768397747 degrees
# Approximate angle of elbow: 162.91296129018616 degrees
# Elbow-down configuation: Shoulder at  178.78797595265533  degrees, and elbow at  342.91296129018616  degrees
#
# Upper arm length: 6.517446886835096
# Lower arm length: 1.5135601446230063
# Shoulder: 47.08290399201126
# Elbow 90.30076800307374
# Horizonal: 3.3241512657575747
# Vertical: 5.797795384124012
# Bisection
# f(a)f(b)<0 not satisfied
#
# Fixed-point
# The first fixed point iteration diverges
#
# Newton
# Approximate angle of shoulder: 47.08290399201127 degrees
# Approximate angle of elbow: 355.53342401160023 degrees
# Elbow-down configuation: Shoulder at  46.046615642037786  degrees, and elbow at  175.53342401160023  degrees
#
# Upper arm length: 0.20771904906486283
# Lower arm length: 2.604458580921202
# Shoulder: 178.92300133225953
# Elbow 210.49904692953598
# Horizonal: 2.0608657646369917
# Vertical: 1.2833158599502623
# Bisection
# f(a)f(b)<0 not satisfied
#
# Fixed-point
# Approximate angle of shoulder: 244.89898649281668  degrees
# The second fixed point iteration diverges
#
# Newton
# Approximate angle of shoulder: 244.89863334895554 degrees
# Approximate angle of elbow: 260.701780231625 degrees
# Elbow-down configuation could not be found.
#
# Upper arm length: 1.7981342683979296
# Lower arm length: 5.379326603564794
# Shoulder: 108.129790842925
# Elbow 110.97722005526965
# Horizonal: -4.733718452064801
# Vertical: -1.6842577264292
# Bisection
# f(a)f(b)<0 not satisfied
#
# Fixed-point
# The first fixed point iteration diverges
#
# Newton
# Approximate angle of shoulder: 291.04134148926454 degrees
# Approximate angle of elbow: 68.89453707674066 degrees
# Elbow-down configuation could not be found.
#
# Upper arm length: 2.4391369176123834
# Lower arm length: 8.66370984100289
# Shoulder: 172.2813754263107
# Elbow 54.739097405617905
# Horizonal: -8.323408819492624
# Vertical: -6.0107507702354415
# Bisection
# Shoulder interval: [ 172.28136981749503 172.28173955809024 ]
# Approximate  angle 172.2815546877926  degrees has been obtained in 20 steps
# g(d)g(e)<0 not satisfied
#
# Fixed-point
# The first fixed point iteration diverges
#
# Newton
# Approximate angle of shoulder: 172.28137542631066 degrees
# Approximate angle of elbow: 140.698151742836 degrees
# Elbow-down configuation could not be found.
#
# Upper arm length: 6.475265722535908
# Lower arm length: 9.264699894451635
# Shoulder: 35.64821823649284
# Elbow 327.4275047160101
# Horizonal: 14.513223464340012
# Vertical: 4.270934552065023
# Bisection
# Shoulder interval: [ 35.64782712581075 35.648230847606555 ]
# Approximate  angle 35.64802898670865  degrees has been obtained in 18 steps
# g(d)g(e)<0 not satisfied
#
# Fixed-point
# The first fixed point iteration diverges
#
# Newton
# Approximate angle of shoulder: 35.64821823649284 degrees
# Approximate angle of elbow: 327.42750471601 degrees
# Elbow-down configuation: Shoulder at  345.26869925474466  degrees, and elbow at  147.42750471601  degrees
#
# Upper arm length: 3.5941109548819474
# Lower arm length: 3.7654588314825057
# Shoulder: 201.91403403665774
# Elbow 211.44404090969067
# Horizonal: -1.0871463648309043
# Vertical: 1.6799563160022815
# Bisection
# f(a)f(b)<0 not satisfied
#
# Fixed-point
# The first fixed point iteration diverges
#
# Newton
# Approximate angle of shoulder: 201.91403403665774 degrees
# Approximate angle of elbow: 284.72789101699453 degrees
# Elbow-down configuation could not be found.
#
# Upper arm length: 9.20195095950528
# Lower arm length: 5.257324287504814
# Shoulder: 241.87558029130477
# Elbow 120.5615181568187
# Horizonal: 0.9148816105110056
# Vertical: -7.891885232835515
# Bisection
# Shoulder interval: [ 241.87540529949675 241.87569623577807 ]
# Approximate  angle 241.87555076763738  degrees has been obtained in 21 steps
# g(d)g(e)<0 not satisfied
#
# Fixed-point
# The first fixed point iteration diverges
#
# Newton
# Approximate angle of shoulder: 311.34962743745285 degrees
# Approximate angle of elbow: 37.86226328198564 degrees
# Elbow-down configuation: Shoulder at  331.87736541341377  degrees, and elbow at  217.86226328198563  degrees
#
# Upper arm length: 0.23250175059766787
# Lower arm length: 2.220424792047886
# Shoulder: 53.68031297657888
# Elbow 249.5544156303519
# Horizonal: 1.3546573798624029
# Vertical: -1.6699025100196376
# Bisection
# Shoulder interval: [ 53.680058768155426 53.68044339774036 ]
# Approximate  angle 53.68025108294789  degrees has been obtained in 20 steps
# Elbow interval: [ 183.08475030224542 183.08511334953928 ]
# Approximate  angle 183.08493182589237  degrees has been obtained in 20 steps
# Elbow-down configuation: Shoulder at  22.752791489919623  degrees, and elbow at  3.0849318258923404  degrees
#
# Fixed-point
# Approximate angle of shoulder: 204.41895558403988  degrees
# Approximate angle of elbow: 20.716325790477526  degrees
# Elbow-down configuation could not be found.
#
# Newton
# Approximate angle of shoulder: 204.41895932320122 degrees
# Approximate angle of elbow: 110.44558436964839 degrees
# Elbow-down configuation could not be found.
#
# Upper arm length: 0.6875247781768412
# Lower arm length: 6.348364040158659
# Shoulder: 266.05298903106046
# Elbow 131.62765982713802
# Horizonal: 4.976960928337018
# Vertical: 3.1946055214037363
# Bisection
# f(a)f(b)<0 not satisfied
#
# Fixed-point
# The first fixed point iteration diverges
#
# Newton
# Approximate angle of shoulder: 159.33809834648068 degrees
# Approximate angle of elbow: 228.37234017286198 degrees
# Elbow-down configuation could not be found.
#
# Upper arm length: 6.293716679662518
# Lower arm length: 6.466473256675377
# Shoulder: 325.44311709304174
# Elbow 158.71349077602693
# Horizonal: 1.5526294359887607
# Vertical: 1.7810975022273996
# Bisection
# f(a)f(b)<0 not satisfied
#
# Fixed-point
# The first fixed point iteration diverges
#
# Newton
# Approximate angle of shoulder: 132.39784899012332 degrees
# Approximate angle of elbow: 73.91779279581623 degrees
# Elbow-down configuation: Shoulder at  213.2351233807765  degrees, and elbow at  253.91779279581624  degrees
#
# Upper arm length: 7.259593156070958
# Lower arm length: 4.932287861524226
# Shoulder: 276.88148093580463
# Elbow 131.5280485929087
# Horizonal: 4.143876787002597
# Vertical: -3.518395879023861
# Bisection
# Shoulder interval: [ 2.4519952042051627 2.452444946539023 ]
# Approximate  angle 2.452220075372093  degrees has been obtained in 20 steps
# g(d)g(e)<0 not satisfied
#
# Fixed-point
# The first fixed point iteration diverges
#
# Newton
# Approximate angle of shoulder: 276.8814809344759 degrees
# Approximate angle of elbow: 214.70898953646656 degrees
# Elbow-down configuation: Shoulder at  254.1218746194289  degrees, and elbow at  34.70898953646656  degrees
#
# Upper arm length: 4.300333853861167
# Lower arm length: 8.96260772768843
# Shoulder: 175.10519360992106
# Elbow 324.87633765610093
# Horizonal: -11.148549155658838
# Vertical: 6.1301989107962775
# Bisection
# f(a)f(b)<0 not satisfied
#
# Fixed-point
# The first fixed point iteration diverges
#
# Newton
# Approximate angle of shoulder: 175.10519361014684 degrees
# Approximate angle of elbow: 224.91327512396487 degrees
# Elbow-down configuation could not be found.
#
# Upper arm length: 1.8488288787735518
# Lower arm length: 6.598394678917502
# Shoulder: 283.2667732400988
# Elbow 356.9701230366316
# Horizonal: 1.5969358400457176
# Vertical: -8.292844816425273
# Bisection
# f(a)f(b)<0 not satisfied
#
# Fixed-point
# Approximate angle of shoulder: 278.5331010053269  degrees
# Approximate angle of elbow: 339.90406967181775  degrees
# Elbow-down configuation could not be found.
#
# Newton
# Approximate angle of shoulder: 283.2667732401 degrees
# Approximate angle of elbow: 336.4963304826078 degrees
# Elbow-down configuation could not be found.
#
# Upper arm length: 4.680982772254093
# Lower arm length: 6.845020541327555
# Shoulder: 60.04414373757708
# Elbow 329.516626502585
# Horizonal: 8.291391607025977
# Vertical: 7.432618395134309
# Bisection
# f(a)f(b)<0 not satisfied
#
# Fixed-point
# The first fixed point iteration diverges
#
# Newton
# Approximate angle of shoulder: 23.703603142930746 degrees
# Approximate angle of elbow: 30.48337349742135 degrees
# Elbow-down configuation: Shoulder at  71.58941482685782  degrees, and elbow at  210.48337349742135  degrees
#
# Upper arm length: 0.6749650032757382
# Lower arm length: 3.6233420764468907
# Shoulder: 66.59112028277254
# Elbow 185.04443194403865
# Horizonal: -0.8734139356746493
# Vertical: -2.819400686579883
# Bisection
# f(a)f(b)<0 not satisfied
#
# Fixed-point
# Approximate angle of shoulder: 78.98489612944968  degrees
# The second fixed point iteration diverges
#
# Newton
# Approximate angle of shoulder: 66.5911202827703 degrees
# Approximate angle of elbow: 185.04443194404038 degrees
# Elbow-down configuation: Shoulder at  38.425896061315406  degrees, and elbow at  5.0444319440404115  degrees
#
# Upper arm length: 8.492269413901475
# Lower arm length: 9.567835990814439
# Shoulder: 9.765640505293186
# Elbow 97.08986161867021
# Horizonal: 5.594934410074754
# Vertical: 10.597239088510847
# Bisection
# f(a)f(b)<0 not satisfied
#
# Fixed-point
# The first fixed point iteration diverges
#
# Newton
# Approximate angle of shoulder: 9.76564050529265 degrees
# Approximate angle of elbow: 63.378857370745564 degrees
# Elbow-down configuation could not be found.
